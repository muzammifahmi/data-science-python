# %% [markdown]
# <a href="https://colab.research.google.com/github/muzammifahmi/data-science-python/blob/main/histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/dataset_statistic.csv", sep = ';')
plt.clf()

# %% [markdown]
# ## melihat distribusi data kolom 'Pendapatan' menggunakan 'hist' dari pandas

# %%
plt.figure()
raw_data.hist(column= "Pendapatan")
plt.title('.hist dari pandas', size = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## melihat distribusi data kolom 'Pendapatan' menggunakan '.hist' dari matplotlib.pyplot

# %%
plt.figure()
plt.hist(x = "Pendapatan", data = raw_data)
plt.xlabel('Pendapatan')
plt.title('Hist dari matplotlib', size = 14)
plt.tight_layout()
plt.show()
